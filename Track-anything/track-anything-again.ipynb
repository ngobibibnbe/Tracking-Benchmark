# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os 
for dirname, _, filenames in os.walk('input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#mask = np.load('/home/sophie/uncertain-identity-aware-tracking/evaluations/input/video-mask-state/state.npy', allow_pickle=True).item()


# Replace 'your_file.npy' with the path to your .npy file
data = np.load('/home/sophie/uncertain-identity-aware-tracking/evaluations/input/video-mask-state/state.npy', allow_pickle=True).item()

np.array(data["masks"]).shape
# Out:
# (15, 720, 1280)

# %%
# %cd /home/sophie/uncertain-identity-aware-tracking/evaluations
# Out:
# /home/sophie/uncertain-identity-aware-tracking/evaluations

# %%
# !pip install gdown
# !gdown --id 1ETbwx9tg2P_Ib1c_zC_Q4pUurX-877lb
#!ffmpeg -i /tmp/1_5084976154427786487.mp4 -ss 0 -t 30 -r 24  /tmp/video.mp4
# Out:
# Requirement already satisfied: gdown in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gdown) (3.15.4)
# Requirement already satisfied: requests[socks] in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gdown) (4.66.4)
# Requirement already satisfied: soupsieve>1.2 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from requests[socks]->gdown) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from requests[socks]->gdown) (2024.7.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from requests[socks]->gdown) (1.7.1)
# /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1ETbwx9tg2P_Ib1c_zC_Q4pUurX-877lb
# To: /home/sophie/uncertain-identity-aware-tracking/evaluations/1_5084976154427786487.mp4
# 100%|██████████████████████████████████████| 79.3M/79.3M [00:02<00:00, 28.8MB/s]

# %%
#!git clone https://github.com/gaomingqi/Track-Anything.git
# !pip install -r Track-Anything/requirements.txt
#!pip install mmcv-lite
# Out:
# Collecting git+https://github.com/cheind/py-thin-plate-spline (from -r Track-Anything/requirements.txt (line 4))
#   Cloning https://github.com/cheind/py-thin-plate-spline to /tmp/pip-req-build-0q40kglj
#   Running command git clone --filter=blob:none --quiet https://github.com/cheind/py-thin-plate-spline /tmp/pip-req-build-0q40kglj
#   Resolved https://github.com/cheind/py-thin-plate-spline to commit f6995795397118b7d0ac01aecd3f39ffbfad9dee
#   Preparing metadata (setup.py) ... done
# Collecting git+https://github.com/facebookresearch/segment-anything.git (from -r Track-Anything/requirements.txt (line 8))
#   Cloning https://github.com/facebookresearch/segment-anything.git to /tmp/pip-req-build-jdc0r4e9
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/segment-anything.git /tmp/pip-req-build-jdc0r4e9
#   Resolved https://github.com/facebookresearch/segment-anything.git to commit 6fdee8f2727f4506cfbbe553e23b895e27956588
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: progressbar2 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from -r Track-Anything/requirements.txt (line 1)) (4.4.2)
# Requirement already satisfied: gdown in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from -r Track-Anything/requirements.txt (line 2)) (5.2.0)
# Requirement already satisfied: gitpython in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from -r Track-Anything/requirements.txt (line 3)) (3.1.43)
# Requirement already satisfied: hickle in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from -r Track-Anything/requirements.txt (line 5)) (5.0.3)
# Requirement already satisfied: tensorboard in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from -r Track-Anything/requirements.txt (line 6)) (2.17.0)
# Requirement already satisfied: numpy in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from -r Track-Anything/requirements.txt (line 7)) (2.0.0)
# Requirement already satisfied: gradio in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from -r Track-Anything/requirements.txt (line 9)) (4.38.1)
# Requirement already satisfied: opencv-python in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from -r Track-Anything/requirements.txt (line 10)) (4.10.0.84)
# Requirement already satisfied: matplotlib in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from -r Track-Anything/requirements.txt (line 11)) (3.9.1)
# Requirement already satisfied: pyyaml in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from -r Track-Anything/requirements.txt (line 12)) (6.0.1)
# Requirement already satisfied: av in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from -r Track-Anything/requirements.txt (line 13)) (12.2.0)
# Requirement already satisfied: openmim in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from -r Track-Anything/requirements.txt (line 14)) (0.3.9)
# Requirement already satisfied: tqdm in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from -r Track-Anything/requirements.txt (line 15)) (4.66.4)
# Requirement already satisfied: psutil in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from -r Track-Anything/requirements.txt (line 16)) (6.0.0)
# Requirement already satisfied: python-utils>=3.8.1 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from progressbar2->-r Track-Anything/requirements.txt (line 1)) (3.8.2)
# Requirement already satisfied: beautifulsoup4 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gdown->-r Track-Anything/requirements.txt (line 2)) (4.12.3)
# Requirement already satisfied: filelock in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gdown->-r Track-Anything/requirements.txt (line 2)) (3.15.4)
# Requirement already satisfied: requests[socks] in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gdown->-r Track-Anything/requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gitpython->-r Track-Anything/requirements.txt (line 3)) (4.0.11)
# Requirement already satisfied: torch>=0.4.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from thinplate==1.0.0->-r Track-Anything/requirements.txt (line 4)) (2.3.1)
# Requirement already satisfied: torchvision>=0.2.1 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from thinplate==1.0.0->-r Track-Anything/requirements.txt (line 4)) (0.18.1)
# Requirement already satisfied: h5py>=2.10.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from hickle->-r Track-Anything/requirements.txt (line 5)) (3.11.0)
# Requirement already satisfied: absl-py>=0.4 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from tensorboard->-r Track-Anything/requirements.txt (line 6)) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from tensorboard->-r Track-Anything/requirements.txt (line 6)) (1.65.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from tensorboard->-r Track-Anything/requirements.txt (line 6)) (3.6)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from tensorboard->-r Track-Anything/requirements.txt (line 6)) (4.25.3)
# Requirement already satisfied: setuptools>=41.0.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from tensorboard->-r Track-Anything/requirements.txt (line 6)) (71.0.3)
# Requirement already satisfied: six>1.9 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from tensorboard->-r Track-Anything/requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from tensorboard->-r Track-Anything/requirements.txt (line 6)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from tensorboard->-r Track-Anything/requirements.txt (line 6)) (3.0.3)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (23.2.1)
# Requirement already satisfied: altair<6.0,>=5.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (5.3.0)
# Requirement already satisfied: fastapi in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (0.111.1)
# Requirement already satisfied: ffmpy in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (0.3.2)
# Requirement already satisfied: gradio-client==1.1.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (1.1.0)
# Requirement already satisfied: httpx>=0.24.1 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (0.24.0)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (6.4.0)
# Requirement already satisfied: jinja2<4.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (2.1.5)
# Requirement already satisfied: orjson~=3.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (3.10.6)
# Requirement already satisfied: packaging in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (2.2.2)
# Requirement already satisfied: pillow<11.0,>=8.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (10.4.0)
# Requirement already satisfied: pydantic>=2.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (2.8.2)
# Requirement already satisfied: pydub in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (0.0.9)
# Requirement already satisfied: ruff>=0.2.2 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (0.5.3)
# Requirement already satisfied: semantic-version~=2.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (0.12.3)
# Requirement already satisfied: typing-extensions~=4.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (4.12.2)
# Requirement already satisfied: urllib3~=2.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (2.2.2)
# Requirement already satisfied: uvicorn>=0.14.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio->-r Track-Anything/requirements.txt (line 9)) (0.30.1)
# Requirement already satisfied: fsspec in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio-client==1.1.0->gradio->-r Track-Anything/requirements.txt (line 9)) (2024.6.1)
# Requirement already satisfied: websockets<12.0,>=10.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gradio-client==1.1.0->gradio->-r Track-Anything/requirements.txt (line 9)) (11.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from matplotlib->-r Track-Anything/requirements.txt (line 11)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from matplotlib->-r Track-Anything/requirements.txt (line 11)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from matplotlib->-r Track-Anything/requirements.txt (line 11)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from matplotlib->-r Track-Anything/requirements.txt (line 11)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from matplotlib->-r Track-Anything/requirements.txt (line 11)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from matplotlib->-r Track-Anything/requirements.txt (line 11)) (2.9.0)
# Requirement already satisfied: Click in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from openmim->-r Track-Anything/requirements.txt (line 14)) (8.1.7)
# Requirement already satisfied: colorama in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from openmim->-r Track-Anything/requirements.txt (line 14)) (0.4.6)
# Requirement already satisfied: model-index in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from openmim->-r Track-Anything/requirements.txt (line 14)) (0.1.11)
# Requirement already satisfied: opendatalab in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from openmim->-r Track-Anything/requirements.txt (line 14)) (0.0.10)
# Requirement already satisfied: pip>=19.3 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from openmim->-r Track-Anything/requirements.txt (line 14)) (24.0)
# Requirement already satisfied: rich in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from openmim->-r Track-Anything/requirements.txt (line 14)) (13.7.1)
# Requirement already satisfied: tabulate in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from openmim->-r Track-Anything/requirements.txt (line 14)) (0.9.0)
# Requirement already satisfied: jsonschema>=3.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from altair<6.0,>=5.0->gradio->-r Track-Anything/requirements.txt (line 9)) (4.23.0)
# Requirement already satisfied: toolz in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from altair<6.0,>=5.0->gradio->-r Track-Anything/requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython->-r Track-Anything/requirements.txt (line 3)) (5.0.1)
# Requirement already satisfied: anyio in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from httpx>=0.24.1->gradio->-r Track-Anything/requirements.txt (line 9)) (4.4.0)
# Requirement already satisfied: certifi in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from httpx>=0.24.1->gradio->-r Track-Anything/requirements.txt (line 9)) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from httpx>=0.24.1->gradio->-r Track-Anything/requirements.txt (line 9)) (1.0.5)
# Requirement already satisfied: idna in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from httpx>=0.24.1->gradio->-r Track-Anything/requirements.txt (line 9)) (3.7)
# Requirement already satisfied: sniffio in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from httpx>=0.24.1->gradio->-r Track-Anything/requirements.txt (line 9)) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio->-r Track-Anything/requirements.txt (line 9)) (0.14.0)
# Requirement already satisfied: pytz>=2020.1 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio->-r Track-Anything/requirements.txt (line 9)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio->-r Track-Anything/requirements.txt (line 9)) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from pydantic>=2.0->gradio->-r Track-Anything/requirements.txt (line 9)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from pydantic>=2.0->gradio->-r Track-Anything/requirements.txt (line 9)) (2.20.1)
# Requirement already satisfied: sympy in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from torch>=0.4.0->thinplate==1.0.0->-r Track-Anything/requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: networkx in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from torch>=0.4.0->thinplate==1.0.0->-r Track-Anything/requirements.txt (line 4)) (3.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from torch>=0.4.0->thinplate==1.0.0->-r Track-Anything/requirements.txt (line 4)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from torch>=0.4.0->thinplate==1.0.0->-r Track-Anything/requirements.txt (line 4)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from torch>=0.4.0->thinplate==1.0.0->-r Track-Anything/requirements.txt (line 4)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from torch>=0.4.0->thinplate==1.0.0->-r Track-Anything/requirements.txt (line 4)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from torch>=0.4.0->thinplate==1.0.0->-r Track-Anything/requirements.txt (line 4)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from torch>=0.4.0->thinplate==1.0.0->-r Track-Anything/requirements.txt (line 4)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from torch>=0.4.0->thinplate==1.0.0->-r Track-Anything/requirements.txt (line 4)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from torch>=0.4.0->thinplate==1.0.0->-r Track-Anything/requirements.txt (line 4)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from torch>=0.4.0->thinplate==1.0.0->-r Track-Anything/requirements.txt (line 4)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from torch>=0.4.0->thinplate==1.0.0->-r Track-Anything/requirements.txt (line 4)) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from torch>=0.4.0->thinplate==1.0.0->-r Track-Anything/requirements.txt (line 4)) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=0.4.0->thinplate==1.0.0->-r Track-Anything/requirements.txt (line 4)) (12.5.82)
# Requirement already satisfied: shellingham>=1.3.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio->-r Track-Anything/requirements.txt (line 9)) (1.5.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from rich->openmim->-r Track-Anything/requirements.txt (line 14)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from rich->openmim->-r Track-Anything/requirements.txt (line 14)) (2.18.0)
# Requirement already satisfied: soupsieve>1.2 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from beautifulsoup4->gdown->-r Track-Anything/requirements.txt (line 2)) (2.5)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from fastapi->gradio->-r Track-Anything/requirements.txt (line 9)) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from fastapi->gradio->-r Track-Anything/requirements.txt (line 9)) (0.0.4)
# Requirement already satisfied: email_validator>=2.0.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from fastapi->gradio->-r Track-Anything/requirements.txt (line 9)) (2.2.0)
# Requirement already satisfied: ordered-set in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from model-index->openmim->-r Track-Anything/requirements.txt (line 14)) (4.1.0)
# Requirement already satisfied: pycryptodome in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from opendatalab->openmim->-r Track-Anything/requirements.txt (line 14)) (3.20.0)
# Requirement already satisfied: openxlab in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from opendatalab->openmim->-r Track-Anything/requirements.txt (line 14)) (0.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from requests[socks]->gdown->-r Track-Anything/requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from requests[socks]->gdown->-r Track-Anything/requirements.txt (line 2)) (1.7.1)
# Requirement already satisfied: dnspython>=2.0.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from email_validator>=2.0.0->fastapi->gradio->-r Track-Anything/requirements.txt (line 9)) (2.6.1)
# Requirement already satisfied: attrs>=22.2.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6.0,>=5.0->gradio->-r Track-Anything/requirements.txt (line 9)) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6.0,>=5.0->gradio->-r Track-Anything/requirements.txt (line 9)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6.0,>=5.0->gradio->-r Track-Anything/requirements.txt (line 9)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6.0,>=5.0->gradio->-r Track-Anything/requirements.txt (line 9)) (0.19.0)
# Requirement already satisfied: mdurl~=0.1 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->openmim->-r Track-Anything/requirements.txt (line 14)) (0.1.2)
# Requirement already satisfied: httptools>=0.5.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from uvicorn[standard]>=0.12.0->fastapi->gradio->-r Track-Anything/requirements.txt (line 9)) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from uvicorn[standard]>=0.12.0->fastapi->gradio->-r Track-Anything/requirements.txt (line 9)) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from uvicorn[standard]>=0.12.0->fastapi->gradio->-r Track-Anything/requirements.txt (line 9)) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from uvicorn[standard]>=0.12.0->fastapi->gradio->-r Track-Anything/requirements.txt (line 9)) (0.22.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/sophie/miniconda3/envs/track_anything/lib/python3.12/site-packages (from sympy->torch>=0.4.0->thinplate==1.0.0->-r Track-Anything/requirements.txt (line 4)) (1.3.0)

# %%
import sys
# !pwd
# %cd /home/sophie/uncertain-identity-aware-tracking/evaluations/Track-Anything
sys.path.append("/home/sophie/uncertain-identity-aware-tracking/evaluations/Track-Anything")
sys.path.append("/home/sophie/uncertain-identity-aware-tracking/evaluations/Track-Anything/tracker")
sys.path.append("/home/sophie/uncertain-identity-aware-tracking/evaluations/Track-Anything/tracker/model")
# Out:
# /home/sophie/uncertain-identity-aware-tracking/evaluations
# /home/sophie/uncertain-identity-aware-tracking/evaluations/Track-Anything

# %%
import argparse
import gdown
import cv2
import numpy as np
import os
import sys

from track_anything import TrackingAnything
from track_anything import parse_augment
import requests
import json
import torchvision
import torch 
from tools.painter import mask_painter
import psutil
import time
try: 
    from mmcv.cnn import ConvModule
except:
    os.system("mim install mmcv")

# %%
# download checkpoints
def download_checkpoint(url, folder, filename):
    os.makedirs(folder, exist_ok=True)
    filepath = os.path.join(folder, filename)

    if not os.path.exists(filepath):
        print("download checkpoints ......")
        response = requests.get(url, stream=True)
        with open(filepath, "wb") as f:
            for chunk in response.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)

        print("download successfully!")

    return filepath

def download_checkpoint_from_google_drive(file_id, folder, filename):
    os.makedirs(folder, exist_ok=True)
    filepath = os.path.join(folder, filename)

    if not os.path.exists(filepath):
        print("Downloading checkpoints from Google Drive... tips: If you cannot see the progress bar, please try to download it manuall \
              and put it in the checkpointes directory. E2FGVI-HQ-CVPR22.pth: https://github.com/MCG-NKU/E2FGVI(E2FGVI-HQ model)")
        url = f"https://drive.google.com/uc?id={file_id}"
        gdown.download(url, filepath, quiet=False)
        print("Downloaded successfully!")

    return filepath

# convert points input to prompt state
def get_prompt(click_state, click_input):
    inputs = json.loads(click_input)
    points = click_state[0]
    labels = click_state[1]
    for input in inputs:
        points.append(input[:2])
        labels.append(input[2])
    click_state[0] = points
    click_state[1] = labels
    prompt = {
        "prompt_type":["click"],
        "input_point":click_state[0],
        "input_label":click_state[1],
        "multimask_output":"True",
    }
    return prompt


# extract frames from upload video
def get_frames_from_video(video_input, video_state):
    """
    Args:
        video_path:str
        timestamp:float64
    Return 
        [[0:nearest_frame], [nearest_frame:], nearest_frame]
    """
    video_path = video_input
    frames = []
    user_name = time.time()
    operation_log = [("",""),("Upload video already. Try click the image for adding targets to track and inpaint.","Normal")]
    try:
        cap = cv2.VideoCapture(video_path)
        fps = cap.get(cv2.CAP_PROP_FPS)
        while cap.isOpened():
            ret, frame = cap.read()
            if ret == True:
                current_memory_usage = psutil.virtual_memory().percent
                frames.append(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
                if current_memory_usage > 90:
                    operation_log = [("Memory usage is too high (>90%). Stop the video extraction. Please reduce the video resolution or frame rate.", "Error")]
                    print("Memory usage is too high (>90%). Please reduce the video resolution or frame rate.")
                    break
            else:
                break
    except (OSError, TypeError, ValueError, KeyError, SyntaxError) as e:
        print("read_frame_source:{} error. {}\n".format(video_path, str(e)))
    image_size = (frames[0].shape[0],frames[0].shape[1]) 
    
    frame_ = np.memmap('/tmp/fps.npy',mode='w+', shape=(len(frames), *frames[0].shape))
    frame_[:] = frames
    del frames
    frame_.flush()
    frames=frame_
    # initialize video_state
    video_state = {
        "user_name": user_name,
        "video_name": os.path.split(video_path)[-1],
        "origin_images": frames,
        #"painted_images": frames.copy(),
        "masks": [np.zeros((frames[0].shape[0],frames[0].shape[1]), np.uint8)]*len(frames),
        "logits": [None]*len(frames),
        "select_frame_number": 0,
        "fps": fps
        }
    video_info = "Video Name: {}, FPS: {}, Total Frames: {}, Image Size:{}".format(video_state["video_name"], video_state["fps"], len(frames), image_size)
    model.samcontroler.sam_controler.reset_image() 
    model.samcontroler.sam_controler.set_image(video_state["origin_images"][0])
    return video_state, video_info, video_state["origin_images"][0]

def run_example(example):
    return video_input
# get the select frame from gradio slider
def select_template(image_selection_slider, video_state, interactive_state, mask_dropdown):

    # images = video_state[1]
    image_selection_slider -= 1
    video_state["select_frame_number"] = image_selection_slider

    # once select a new template frame, set the image in sam

    model.samcontroler.sam_controler.reset_image()
    model.samcontroler.sam_controler.set_image(video_state["origin_images"][image_selection_slider])

    # update the masks when select a new template frame
    # if video_state["masks"][image_selection_slider] is not None:
        # video_state["painted_images"][image_selection_slider] = mask_painter(video_state["origin_images"][image_selection_slider], video_state["masks"][image_selection_slider])
    if mask_dropdown:
        print("ok")
    operation_log = [("",""), ("Select frame {}. Try click image and add mask for tracking.".format(image_selection_slider),"Normal")]


    return video_state["painted_images"][image_selection_slider], video_state, interactive_state, operation_log

# set the tracking end frame
def get_end_number(track_pause_number_slider, video_state, interactive_state):
    interactive_state["track_end_number"] = track_pause_number_slider
    operation_log = [("",""),("Set the tracking finish at frame {}".format(track_pause_number_slider),"Normal")]

    return video_state["painted_images"][track_pause_number_slider],interactive_state, operation_log

def get_resize_ratio(resize_ratio_slider, interactive_state):
    interactive_state["resize_ratio"] = resize_ratio_slider

    return interactive_state

# use sam to get the mask
def sam_refine(video_state, point_prompt, click_state, interactive_state, evt):
    """
    Args:
        template_frame: PIL.Image
        point_prompt: flag for positive or negative button click
        click_state: [[points], [labels]]
    """
    if point_prompt == "Positive":
        coordinate = "[[{},{},1]]".format(evt.index[0], evt.index[1])
        interactive_state["positive_click_times"] += 1
    else:
        coordinate = "[[{},{},0]]".format(evt.index[0], evt.index[1])
        interactive_state["negative_click_times"] += 1
    
    # prompt for sam model
    model.samcontroler.sam_controler.reset_image()
    model.samcontroler.sam_controler.set_image(video_state["origin_images"][video_state["select_frame_number"]])
    prompt = get_prompt(click_state=click_state, click_input=coordinate)

    mask, logit, painted_image = model.first_frame_click( 
                                                      image=video_state["origin_images"][video_state["select_frame_number"]], 
                                                      points=np.array(prompt["input_point"]),
                                                      labels=np.array(prompt["input_label"]),
                                                      multimask=prompt["multimask_output"],
                                                      )
    video_state["masks"][video_state["select_frame_number"]] = mask
    video_state["logits"][video_state["select_frame_number"]] = logit
    video_state["painted_images"][video_state["select_frame_number"]] = painted_image

    operation_log = [("",""), ("Use SAM for segment. You can try add positive and negative points by clicking. Or press Clear clicks button to refresh the image. Press Add mask button when you are satisfied with the segment","Normal")]
    return painted_image, video_state, interactive_state, operation_log

import numpy as np
def add_multi_mask(video_state, interactive_state, mask_dropdown):
    try:
        mask = video_state["masks"][video_state["select_frame_number"]]
        interactive_state["multi_mask"]["masks"].append(mask)
        interactive_state["multi_mask"]["mask_names"].append("mask_{:03d}".format(len(interactive_state["multi_mask"]["masks"])))
        mask_dropdown.append("mask_{:03d}".format(len(interactive_state["multi_mask"]["masks"])))
        select_frame, run_status = show_mask(video_state, interactive_state, mask_dropdown)

        operation_log = [("",""),("Added a mask, use the mask select for target tracking or inpainting.","Normal")]
        np.save("/home/sophie/Calf_assessement/tracked_video/state.npy", interactive_state["multi_mask"])
    except:
        operation_log = [("Please click the left image to generate mask.", "Error"), ("","")]
    return interactive_state, gr.update(choices=interactive_state["multi_mask"]["mask_names"], value=mask_dropdown), select_frame, [[],[]], operation_log

def clear_click(video_state, click_state):
    click_state = [[],[]]
    template_frame = video_state["origin_images"][video_state["select_frame_number"]]
    operation_log = [("",""), ("Clear points history and refresh the image.","Normal")]
    return template_frame, click_state, operation_log

def remove_multi_mask(interactive_state, mask_dropdown):
    interactive_state["multi_mask"]["mask_names"]= []
    interactive_state["multi_mask"]["masks"] = []

    operation_log = [("",""), ("Remove all mask, please add new masks","Normal")]
    return interactive_state, gr.update(choices=[],value=[]), operation_log

def show_mask(video_state, interactive_state, mask_dropdown):
    mask_dropdown.sort()
    select_frame = video_state["origin_images"][video_state["select_frame_number"]]
    for i in range(len(mask_dropdown)):
        mask_number = int(mask_dropdown[i].split("_")[1]) - 1
        mask = interactive_state["multi_mask"]["masks"][mask_number]
        select_frame = mask_painter(select_frame, mask.astype('uint8'), mask_color=mask_number+2)
    
    operation_log = [("",""), ("Select {} for tracking or inpainting".format(mask_dropdown),"Normal")]
    return select_frame, operation_log

# tracking vos
def vos_tracking_video(video_state, interactive_state, mask_dropdown):
    operation_log = [("",""), ("Track the selected masks, and then you can select the masks for inpainting.","Normal")]
    model.xmem.clear_memory()
    
    following_frames = video_state["origin_images"]

    template_mask = interactive_state['masks']
    fps = video_state['fps']

    # operation error
    if len(np.unique(template_mask))==1:
        template_mask[0][0]=1
        operation_log = [("Error! Please add at least one mask to track by clicking the left image.","Error"), ("","")]
        # return video_output, video_state, interactive_state, operation_error
    masks, logits, painted_images = model.generator(images=following_frames, template_mask=template_mask)
    # clear GPU memory
    model.xmem.clear_memory()

    
    video_state["masks"][video_state["select_frame_number"]:] = masks
    video_state["logits"][video_state["select_frame_number"]:] = logits
    video_state["painted_images"] = painted_images

    video_output = generate_video_from_frames(video_state["painted_images"], output_path="/home/sophie/uncertain-identity-aware-tracking/evaluations/input/{}".format(video_state["video_name"]), fps=fps) # import video_input to name the output video

    
    
    # save_mask(video_state["masks"], video_state["video_name"])
    #### shanggao code for mask save
    return video_output, video_state, interactive_state, operation_log

# extracting masks from mask_dropdown
# def extract_sole_mask(video_state, mask_dropdown):
#     combined_masks = 
#     unique_masks = np.unique(combined_masks)
#     return 0 

# inpaint 
def inpaint_video(video_state, interactive_state, mask_dropdown):
    operation_log = [("",""), ("Removed the selected masks.","Normal")]

    frames = np.asarray(video_state["origin_images"])
    fps = video_state["fps"]
    inpaint_masks = np.asarray(video_state["masks"])
    if len(mask_dropdown) == 0:
        mask_dropdown = ["mask_001"]
    mask_dropdown.sort()
    # convert mask_dropdown to mask numbers
    inpaint_mask_numbers = [int(mask_dropdown[i].split("_")[1]) for i in range(len(mask_dropdown))]
    # interate through all masks and remove the masks that are not in mask_dropdown
    unique_masks = np.unique(inpaint_masks)
    num_masks = len(unique_masks) - 1
    for i in range(1, num_masks + 1):
        if i in inpaint_mask_numbers:
            continue
        inpaint_masks[inpaint_masks==i] = 0
    # inpaint for videos

    try:
        inpainted_frames = model.baseinpainter.inpaint(frames, inpaint_masks, ratio=interactive_state["resize_ratio"])   # numpy array, T, H, W, 3
    except:
        operation_log = [("Error! You are trying to inpaint without masks input. Please track the selected mask first, and then press inpaint. If VRAM exceeded, please use the resize ratio to scaling down the image size.","Error"), ("","")]
        inpainted_frames = video_state["origin_images"]
    video_output = generate_video_from_frames(inpainted_frames, output_path="./result/inpaint/{}".format(video_state["video_name"]), fps=fps) # import video_input to name the output video

    return video_output, operation_log


# generate video after vos inference
def generate_video_from_frames(frames, output_path, fps=30):
    """
    Generates a video from a list of frames.
    
    Args:
        frames (list of numpy arrays): The frames to include in the video.
        output_path (str): The path to save the generated video.
        fps (int, optional): The frame rate of the output video. Defaults to 30.
    """
    # height, width, layers = frames[0].shape
    # fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    # video = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
    # print(output_path)
    # for frame in frames:
    #     video.write(frame)
    
    # video.release()
    frames = torch.from_numpy(np.asarray(frames))
    if not os.path.exists(os.path.dirname(output_path)):
        os.makedirs(os.path.dirname(output_path))
    torchvision.io.write_video(output_path, frames, fps=fps, video_codec="libx264")
    return output_path

# %%
# !pwd
# Out:
# /home/sophie/uncertain-identity-aware-tracking/evaluations/Track-Anything

# %%
import PIL
from tqdm import tqdm

from tools.interact_tools import SamControler
from tracker.base_tracker import BaseTracker
from inpainter.base_inpainter import BaseInpainter
import numpy as np
import argparse



class TrackingAnything():
    def __init__(self, sam_checkpoint, xmem_checkpoint, e2fgvi_checkpoint, args):
        self.args = args
        self.sam_checkpoint = sam_checkpoint
        self.xmem_checkpoint = xmem_checkpoint
        self.e2fgvi_checkpoint = e2fgvi_checkpoint
        self.samcontroler = SamControler(self.sam_checkpoint, args.sam_model_type, args.device)
        self.xmem = BaseTracker(self.xmem_checkpoint, device=args.device)
        #self.baseinpainter = BaseInpainter(self.e2fgvi_checkpoint, args.device) 
    # def inference_step(self, first_flag: bool, interact_flag: bool, image: np.ndarray, 
    #                    same_image_flag: bool, points:np.ndarray, labels: np.ndarray, logits: np.ndarray=None, multimask=True):
    #     if first_flag:
    #         mask, logit, painted_image = self.samcontroler.first_frame_click(image, points, labels, multimask)
    #         return mask, logit, painted_image
        
    #     if interact_flag:
    #         mask, logit, painted_image = self.samcontroler.interact_loop(image, same_image_flag, points, labels, logits, multimask)
    #         return mask, logit, painted_image
        
    #     mask, logit, painted_image = self.xmem.track(image, logit)
    #     return mask, logit, painted_image
    
    def first_frame_click(self, image: np.ndarray, points:np.ndarray, labels: np.ndarray, multimask=True):
        mask, logit, painted_image = self.samcontroler.first_frame_click(image, points, labels, multimask)
        return mask, logit, painted_image
    
    # def interact(self, image: np.ndarray, same_image_flag: bool, points:np.ndarray, labels: np.ndarray, logits: np.ndarray=None, multimask=True):
    #     mask, logit, painted_image = self.samcontroler.interact_loop(image, same_image_flag, points, labels, logits, multimask)
    #     return mask, logit, painted_image

    def generator(self, images: list, template_mask:np.ndarray):
        
        masks = []
        logits = []
        painted_images = []
        for i in tqdm(range(len(images)), desc="Tracking image"):
            if i ==0:           
                mask, logit, painted_image = self.xmem.track(images[i], template_mask)
                masks.append(mask)
                logits.append(logit)
                painted_images.append(painted_image)
                
            else:
                mask, logit, painted_image = self.xmem.track(images[i])
                masks.append(mask)
                logits.append(logit)
                painted_images.append(painted_image)
        return masks, logits, painted_images

# %%
from collections import namedtuple
import gc
gc.collect()
# args, defined in track_anything.py
args = namedtuple(
    'Args',['sam_model_type',]
)
args.sam_model_type = "vit_l"
args.mask_save = False

# check and download checkpoints if needed
SAM_checkpoint_dict = {
    'vit_h': "sam_vit_h_4b8939.pth",
    'vit_l': "sam_vit_l_0b3195.pth", 
    "vit_b": "sam_vit_b_01ec64.pth"
}
SAM_checkpoint_url_dict = {
    'vit_h': "https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth",
    'vit_l': "https://dl.fbaipublicfiles.com/segment_anything/sam_vit_l_0b3195.pth",
    'vit_b': "https://dl.fbaipublicfiles.com/segment_anything/sam_vit_b_01ec64.pth"
}
sam_checkpoint = SAM_checkpoint_dict[args.sam_model_type] 
sam_checkpoint_url = SAM_checkpoint_url_dict[args.sam_model_type] 
xmem_checkpoint = "XMem-s012.pth"
xmem_checkpoint_url = "https://github.com/hkchengrex/XMem/releases/download/v1.0/XMem-s012.pth"
e2fgvi_checkpoint = "E2FGVI-HQ-CVPR22.pth"
e2fgvi_checkpoint_id = "10wGdKSUOie0XmCr8SQ2A2FeDe-mfn5w3"


folder ="./checkpoints"
SAM_checkpoint = download_checkpoint(sam_checkpoint_url, folder, sam_checkpoint)
xmem_checkpoint = download_checkpoint(xmem_checkpoint_url, folder, xmem_checkpoint)
e2fgvi_checkpoint = download_checkpoint_from_google_drive(e2fgvi_checkpoint_id, folder, e2fgvi_checkpoint)
args.port = 12212
args.device = "cuda"
args.mask_save = False
import torch.nn as nn
# initialize sam, xmem, e2fgvi models
model = TrackingAnything(SAM_checkpoint, xmem_checkpoint, e2fgvi_checkpoint,args)
# Out:
# Initializing BaseSegmenter to cuda
# Hyperparameters read from the model weights: C^k=64, C^v=512, C^h=64
# Single object mode: False

# %%
# %cd /home/sophie/uncertain-identity-aware-tracking/evaluations/Track-Anything/
#/input
# !pwd
# Out:
# /home/sophie/uncertain-identity-aware-tracking/evaluations/Track-Anything
# /home/sophie/uncertain-identity-aware-tracking/evaluations/Track-Anything

# %%
import json
duration = 800
start = 0
mask = np.load('/home/sophie/Calf_assessement/tracked_video/state.npy', allow_pickle=True).item()


template_mask = mask['masks'][0]
for i in range(1,len(mask['masks'])):
        mask_number = i
        template_mask = np.clip(template_mask+mask['masks'][mask_number]*(mask_number+1), 0, mask_number+1)
mask = {'masks': template_mask}


d = {}

"""for start in range(0, 800, duration):
    # !ffmpeg -i 1_5084976154427786487.mp4 -ss {start} -t {duration} -r 24  /tmp/video-{start}.mp4 -y -loglevel error
    """
    
video_path = "/home/sophie/Calf_assessement/videos_sample/Diarrhé/1_clip_3_6768_2_2022-02-18 18:48:57_Diarrhé.mp4"
try:
    video_state, video_info, first_image = get_frames_from_video(video_path, {})
except Exception as e :
    print("error", e)
video_output, video_state, interactive_state, operation_log = vos_tracking_video(video_state, mask, {})

print(video_path)
for i, eps in enumerate(video_state['masks']):
    idx = i  + start * 24
    d[idx] = {}
    for j in range(15):
        ys, xs = np.where(eps==j+1)
        
        
        try:
            xmin, xmax = xs.min(), xs.max()
            ymin, ymax = ys.min(), ys.max()

            d[idx][j] = [int(xmin), int(ymin), int(xmax-xmin), int(ymax-ymin)]
        except:  
            print(f"id: {j} lost on frame:{idx}")
mask = {'masks':eps}
video_path_mask = video_path.split(".mp4")[0]+'-mask-video.npy'
tracking_res= video_path.split(".mp4")[0]+'bbox-tracking.json'
#np.save(f'/home/sophie/uncertain-identity-aware-tracking/evaluations/input/mask-video.npy', eps)
np.save(video_path_mask, eps)

del video_state, video_info, first_image, video_output, interactive_state, operation_log
gc.collect()



with open(tracking_res, 'w') as f:
    json.dump(d, f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 5
#       2 duration = 800
#       3 start = 0
# ----> 5 template_mask = mask['masks'][0]
#       6 for i in range(1,len(mask['masks'])):
#       7         mask_number = i
#
# NameError: name 'mask' is not defined

# %%
import json

with open('trackanything_res.json', 'w') as f:
    json.dump(d, f)
